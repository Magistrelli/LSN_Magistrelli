# %% [markdown]
# # <span style="color:blue">Esercitazione 5</span>

# %% [markdown]
# ### Esercizio 05.1
# L'obbiettivo è qui quello di eseguire una misura della distanza media del raggio dell'atomo di idrogeno (quantistico) attraverso l'utilizzo dell'algoritmo di Metropolis per il sampling del modulo quadro $|\Psi(\vec{r},t)|^2$ della funzione d'onda elettronica, che può a tutti gli effetti essere interpretato come la densità di probabilità che la particella si trovi, al tempo $t$, in un volumetto infinitesimo di spazio centrato intorno alla posizione $\vec{r}$. Questo viene fatto sia per il Ground State ($n=1$, $m=0$, $l=0$), per cui
#
# $$ \Psi_{1,0,0}(r,\theta,\phi)=\frac{a_0^{-3/2}}{\sqrt{\pi}} e^{-r/a_0} $$
#
# sia per lo stato eccitato $2p$ ($n=2$, $m=1$, $l=0$), per cui invece
#
# $$ \Psi_{2,1,0}(r,\theta,\phi)= \frac{a_0^{-5/2}}{8}\sqrt{\frac{2}{\pi}} r e^{-r/2a_0} \cos(\theta) $$
#
# Dove $a_0 = 4\pi\epsilon_0\hbar^2/m_e e^2=0.0529$ è il raggio di Bohr. Essendo gli stati considerati degli autostati dell'Hamiltoniana, questi hanno funzioni d'onda indipendenti dal tempo.\
# Si può dimostrare che per il valore di aspettazione del raggio dell'atomo si ha, nei due casi,
# $$\left\langle r \right\rangle_{\Psi_{1,0,0}} = \frac{3}{2}a_0
# \quad
# \left\langle r \right\rangle_{\Psi_{2,1,0}} = 5 a_0$$

# %% [markdown]
# Dal punto di vista pratico l'*algoritmo di Metropolis* è utilizzato per sondare $|\Psi_{1,0,0}(x,y,z)|^2$ e $|\Psi_{2,1,0}(x,y,z)|^2$ in coordinate cartesiane. Ho eseguito due prove differenti, una con una *probabilità di transizione di prova* $T(\vec{x}|\vec{y})$ uniforme e una con una $T(\vec{x}|\vec{y})$ gaussiana centrata proprio su $\vec{y}$. Queste due funzioni sono entrambe simmetriche nello scambio di $\vec{x}$ e $\vec{y}$, cioè $T(\vec{x}|\vec{y}) = T(\vec{y}|\vec{x})$, e questo permette di utilizzare una forma semplificata (e identica nei due casi, in quanto indipendente da $T$) per l'espressione della *probabilità di accettazione*, $ A(\vec{x}|\vec{y}) = \min{\left[1,q(x|y)\right]}$, con
#
# $$ q(x|y) =
# \frac {T(\vec{y}|\vec{x}) p(\vec{x})} {T(\vec{x}|\vec{y}) p(\vec{y})} =
# \frac {p(\vec{x})} {p(\vec{y})}$$
#
# dove in questo caso $p(\vec{x})$ rappresenta nei due casi i moduli quadri delle funzioni d'onda dei due differenti stati presi in esame.

# %% [markdown]
# Grazie al *teorema di Markov* sappiamo che, passata una prima fase di burn-in (più o meno lunga a seconda della posizione di partenza $\vec{x_0}$ scelta per la serie temporale e delle caratteristiche della probabilità di transizione scelta), i punti che andranno a comporre la catena di Markov prodotta dall'algoritmo di Metropolis secondo la *probabilità di transizione*
# $$K(\vec{x}|\vec{y}) = T(\vec{x}|\vec{y}) A(\vec{x}|\vec{y})$$
# saranno ad ogni passo estratti secondo la distribuzione $p(\vec{x})$ di interesse.\
# Per la misura di $\left\langle r \right\rangle_{\Psi_{1,0,0}}$ e $\left\langle r \right\rangle_{\Psi_{2,1,0}}$ ho quindi lanciato un programma che, dopo $N_{burn} = 2 \times 10^4$ step di equilibrazione, simula altri $M=10^7$ passi della catena di Markov e calcola per ognuno di essi il corrispondente valore di $r$. Questi risultano distribuiti secondo la densità di probabilità $p(\vec{x})$ di interesse, e quindi permettono di stimare in maniera corretta il valore medio $\langle r \rangle$. Per avere una stima adeguata dell'incertezza della misura gli $M$ step sono stati suddivisi in $N_{blk}=100$ blocchi ed è stato utilizzato il *blocking method*.
#
# Qui tale suddivisione è necessaria anche per evitare una sottostima dell'errore commesso nella misura. In una catena di Markov infatti i punti contigui sono tra loro correlati, e quindi non può essere utilizzato in maniera diretta il *teorema del limite centrale*, che può essere invece applicato nel blocking method se si suppone che la dimensione dei blocchi sia sufficiente a produrre medie di blocco sostanzialmente scorrelate tra loro.

# %% [markdown]
# Prima dell'esecuzione vera e propria della simulazione ho lanciato una serie di test più brevi ($M=10^6$) per ottenere dei parametri per le $T(\vec{x}|\vec{y})$ che rispettassero la "regola" empirica dell'accettazione al $50\%$. Ho quindi utilizzato, rispettivamente per lo studio del $GS$ e dello stato $2p$,:
# 1. una $T$ uniforme di larghezza $1.25\ a_0$ e una $T$ gaussiana con $\sigma = 0.75\ a_0$
# 2. una $T$ uniforme di larghezza $3\ a_0$ e una $T$ gaussiana con $\sigma = 2\ a_0$

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as pl
from mpl_toolkits.mplot3d import Axes3D

# %%
def far(if_far):     #if_far=True if starting point is far from the origin
    if if_far: name='_far_'
    else: name='_'
    return name

def burn_fig(if_far):
    if if_far: farfile='_far_'
    else: farfile='_'
    burnGS=np.genfromtxt('results/burn_in'+far(if_far)+'0_0.out',skip_header=1,names='x,r')
    burn210=np.genfromtxt('results/burn_in'+far(if_far)+'0_1.out',skip_header=1,names='x,r')

    pl.figure(figsize=(12,4))
    pl.plot(burn210['x'],burn210['r'],label='$2p$ state')
    pl.plot(burnGS['x'],burnGS['r'],label='GS')
    pl.axhline(y=1.5,color='k',linewidth=0.8,label='expected <r>')
    pl.axhline(y=5,color='k',linewidth=0.8)
    pl.legend(loc='best')
    pl.xlabel('$N_{stp}$')
    pl.ylabel('$r\ [a_0]$',labelpad=15)
    pl.title('Uniform T burn in')
    pl.grid(True)
    pl.show()

# %% [markdown]
# I risultati che seguono sono stati ottenuti scegliendo come $\vec{x_0}$ l'origine degli assi (questo corrisponde a scegliere una distribuzione di probabilità $d_0(\vec{x})$ deltiforme per il punto di partenza). Come si vede direttamente dal grafico sottostante, che riporta le distanze dall'origine esplorate nella fase di burn-in nel caso di $T$ uniforme, la scelta è così buona da rendere la fase di equilibrazione in sostanza non necessaria. Questo è legato al fatto che entrambe le distribuzioni di interesse hanno delle regioni di massimo che vivono nella regione attorno all'origine, e quindi effettivamente a seguito della fase di equilibrazione è qui che il walker passerà la maggior parte del tempo, indipendentemente dalla posizione di partenza scelta (si veda l'appendice per una prova di partenza a $\vec{x_0}=(10^4,10^4,10^4)$).

# %%
burn_fig(False)

# %% [markdown]
# In questo grafico (e ovunque all'interno del programma) tutte le misure di distanza sono espresse in unità del raggio di Bohr.
#
# Il walker mantiene sempre un pattern di esplorazione delle distanze elettrone-nucleo statisticamente invariante, e questo indica il fatto che fin da subito tutti questi punti sono già estratti secondo la distribuzione di interesse $p(\vec{x})$, limite invariante associato al $K(\vec{x},\vec{y}) = T(\vec{x},\vec{y}) A(\vec{x},\vec{y})$ regolare appositamente costruito. In altre parole vale, già per $i$ piuttosto piccolo,
# $$d_{i+1}(\vec{x}) = \int K(\vec{x}|\vec{y}) d_i(\vec{y}) = p(\vec{x}) = \lim_{n \to \infty} d_n(\vec{x}) $$
# Il teorema di Markov assicura che il limite $p(\vec{x})$ è univocamente definito. La stazionarietà del sampling assicura quindi che la convergenza è già stata raggiunta, in quanto nessun'altra distribuzione di probabilità può essere lasciata invariante da $K$.

# %%
title=('Ground State','$2p$ State')
def r_fig(if_far):
    dataGS=np.genfromtxt('results/res'+far(if_far)+'0.out',usecols=(0,2,3),names='x,res,err')
    data210=np.genfromtxt('results/res'+far(if_far)+'1.out',usecols=(0,2,3),names='x,res,err')
    gaussGS=np.genfromtxt('results/res_gauss'+far(if_far)+'0.out',usecols=(0,2,3),names='x,res,err')
    gauss210=np.genfromtxt('results/res_gauss'+far(if_far)+'1.out',usecols=(0,2,3),names='x,res,err')
    data=(dataGS,gaussGS,data210,gauss210)
    r_teo=(1.5,5.)
    
    pl.figure(figsize=(10,10))
    for i in range(2):
        pl.subplot(2,1,i+1)
        pl.errorbar(data[2*i]['x'],data[2*i]['res'],yerr=data[2*i]['err'],label='Uniform T')
        pl.errorbar(data[2*i+1]['x'],data[2*i+1]['res'],yerr=data[2*i+1]['err'],label='Gaussian T')
        pl.axhline(y=r_teo[i],color='k',linewidth=0.8,label='expected <r>')
        pl.legend(loc='best')
        if i==1: pl.xlabel('$N_{blk}$')
        pl.ylabel('$<r>\ [a_0]$',labelpad=15)
        pl.title(title[i])
        pl.grid(True)
    pl.show()

# %% [markdown]
# I grafici seguenti riportano i risultati della stima delle distanze medie con la loro incertezza.

# %%
r_fig(False)

# %% [markdown]
# Come era da aspettarsi, i risultati ottenuti con le diverse $T$ sono tra loro equivalenti. L'algoritmo adatta infatti alla generica $T$ scelta una particolare $A$ (in realtà indipendente da $T$ se questa è simmetrica), e funziona quindi "qualunque" (deve rispettare le condioni di regolarità ed ergodicità del teorema di Markov) sia la probabilità di transizione di prova scelta.\
# Tutti i risultati sono compatibili con la previsione teorica.

# %%
def fig3D(if_far,state):   #state is "GS" or "210"
    if if_far: state+="_far"
    pos=np.genfromtxt('results/'+state+'.config',delimiter=' ',names='x,y,z')

    fig = pl.figure()
    ax = Axes3D(fig)
    ax.scatter(pos['x'], pos['y'], pos['z'], c=pos['z'], marker='.')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')
    ax.view_init(1, 30)
    if (state=="GS") or (state=="GS_far"): pl.title(title[0])
    elif (state=="210") or (state=="210_far"): pl.title(title[1])
    pl.show()

# %% [markdown]
# Rappresento infine con uno scatter plot 3D i punti della catena corrispondenti all'ultimo blocco della catena prodotta col $T$ uniforme.

# %%
fig3D(False,"GS")
fig3D(False,"210")

# %% [markdown]
# La forma delle distribuzioni di probabilità è quella attesa dalla teoria.

# %% [markdown]
# #### Appendice: partenza lontana dall'origine

# %% [markdown]
# Il grafico sottostante mostra la fase di equilibrazione a seguito di una partenza del walker in $\vec{x_0}=(10^4,10^4,10^4)$.

# %%
burn_fig(True)

# %% [markdown]
# Qui è evidente la fase di transizione iniziale. Nella regione di partenza le distribuzioni di probabilità per la distanza dell'elettrone dal nucleo sono praticamente nulle, mentre la larghezza della funzione $T(\vec{x},\vec{y})$ è comunque limitata. E' chiaro quindi che, inizialmente, è impossibile che la probabilità di transizione $K(\vec{x},\vec{y})$ riesca a produrre nella catena di Markov delle configurazioni estratte secondo la distribuzione $p(\vec{x})$, nel senso che vale invece
# $$d_{i+1}(\vec{x}) = \int K(\vec{x}|\vec{y}) d_i(\vec{y}) \neq p(\vec{x}) = \lim_{n \to \infty} d_n(\vec{x}) $$
# D'altra parte sappiamo che il teorema di Markov ci assicura che questo è quello che deve succedere asintoticamente. Di conseguenza il walker che genera la catena non può che avvicinarsi progressivamente all'origine.\
# In altre parole la parte di catena di Markov qui prodotta non è stazionaria (e non lo diventa neanche alla fine del burn-in), e quindi siamo ancora lontani dalla condizione di convergenza asintotica assicurata dal teorema.
#
# In particolare in questo caso $x_0$ è talmente distante da essa che $N_{burn}=2\times 10^4$ non è sufficiente per iniziare da subito, finito il burn-in, a campionare correttamente $p(\vec{x})$.

# %% [markdown]
# Questa conclusione è confermata dal grafico dell'evoluzione della misura di $\left\langle r \right\rangle_{\Psi_{1,0,0}}$ e $\left\langle r \right\rangle_{\Psi_{2,1,0}}$ al crescere del numero di blocchi analizzati, e quindi all'aumentare della lunghezza della catena.

# %%
r_fig(True)

# %% [markdown]
# In tutti i casi considerati i valori medi hanno un andamento estremamente monotono, e questo è coerente col fatto che la catena analizzata non ha ancora raggiunto la fase di stazionarietà (le misure ottenute sono visibilmente funzioni del tempo).

# %% [markdown]
# Probabilmente basterebbe considerare come burn-in le prime decine di blocchi iniziali per avere dei risultati compatibili a quelli analizzati nella parte centrale del problema. Come mostrano gli scatter plot sotto, giunta all'ultimo blocco la convergenza è sostanzialmente stata raggiunta. La forma delle distribuzioni di probabilità nello spazio è infatti compatibile coi risultati precedenti e con la previsione teorica per $p(\vec{x})$.

# %%
fig3D(True,"GS")
fig3D(True,"210")
