# %% [markdown]
# # <span style="color:blue">Esercitazione 11</span>

# %% [markdown]
# L'obiettivo della lezione è di sperimentare l'utilizzo delle reti neurali (*neural network*, NN). In particolare vengono affrontati con delle reti di tipo *feedforward* (modello <font face="Courier">Sequential</font> della libreria <font face="Courier">Keras</font>) tre problemi di regressione lineare.

# %% [markdown]
# Attraverso una serie di tentativi e di sperimentazioni voglio arrivare a costruire delle NN che siano in grado, grazie ad una fase di training correttamente impostata, di adattare i propri parametri liberi in modo che la sequenza di layer e neuroni che le costituiscono riproducano il più accuratamente possibile, nelle loro operazioni collettive di mappatura dell'input, la funzione target del problema. In linea di principio questo obbiettivo è sempre raggiungibile (teorema di approssimazione universale).
#
# In altre parole una NN può essere in generale vista come una trasformazione non lineare che mappa ogni input nel relativo output in un modo che è funzione dei parametri della rete, ovvero del'insieme dei parametri delle funzioni risposta $\psi_i^j$ dei singoli neuroni ($i$ e $j$ sono gli indici rispettivamente di neurone e di layer), ottenute tipicamente componendo una risposta lineare con una funzione di attivazione $\phi_i^j$,
#
# $$ \psi_i^j (\vec{x}_{j-1}) = \phi_i^j \ (\ \vec{x}_{j-1} \cdot \vec{w}_{i,j} + \ b_{i,j}) = x_{i,j}$$
#
# dove ${x}_{j-1}$ è il vettore di output del layer precedente e $\vec{w}_{i,j}$ e $b_{i,j}$ sono rispettivamente i pesi e i bias del neurone considerato.\
# Mentre la forma delle funzioni di attivazione rientra nella creazione e nella struttura della NN, la selezione dei parametri che completano le definizioni delle funzioni risposta viene operata nella fase di training, in cui la macchina apprende quali sono i valori da assegnare ad essi per rappresentare la funzione target il meglio possibile. A questo punto l'approssimazione cercata viene ottenuta andando in ogni layer a utilizzare gli output $x_{i,j}$ dei singoli neuroni come input $\vec{x}_j$ per i layer successivi. Le trasformazioni semplici implementate dai singoli neuroni vengono composte e sovrapposte più volte, e questo permette in generale di approssimare, a un adeguato livello di complessità della rete, qualunque funzione continua con un grado arbitrario di precisione.

# %% [markdown]
# ### Esercizio 11.1
#
# Parto da dati distribuiti secondo la relazione lineare $ f(x)=2x+1 $.
#
# La macchina sarà allenata nell'intervallo $[-1,1]$.

# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD, Adam, Adadelta
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# I dati di training e di validazione sono generati casualmente nell'intervallo $[-1,1]$ di interesse. Nella prima prova $N_{train}=100$ e $N_{valid}=10$ e i dati sono privi di rumore.
#
# Il primo gruppo di dati è utilizzato per cercare di ottimizzare i valori dei parametri minimizzando il *training error* $E_{in}$, il secondo per valutare la validità delle previsioni finali della macchina su dei dati mai visti prima. Nei problemi che seguono il controllo è più immediato nel confronto con la funzione target, ma nei problemi reali questa è sconosciuta e i dati di validazione forniscono l'unico punto di riferimento esistente, reso quantitativo dal calcolo dell'*out-of-sample error* $E_{out}$.\
# In questo primo esercizio l'unica funzione costo utilizzata per il calcolo degli errori è la *mean square-error*,
# $$ MSE= \frac{1}{N_\mathrm{test}}\sum_{j=1}^{N_\mathrm{test}} (y_j^\mathrm{pred}-y_j)^2 $$
# dove $y_j^\mathrm{pred}$ sono le predizioni della rete, $y_j$ gli output veri.

# %%
np.random.seed(0)

def data_gen(ntrain,nvalid,target_f,sigma):  #sigma is noise standard deviation for y train and valid
    #generate training data
    x_train = np.random.uniform(-1, 1, ntrain)
    y_train = np.random.normal(target_f(x_train),sigma)  #actual measures from which we want to guess regression parameters
    #generate validation data
    x_valid = np.random.uniform(-1, 1, nvalid)
    y_valid = np.random.normal(target_f(x_valid),sigma)
    # ideal (target) function
    x_target = x_valid      #the same of x_valid for error evaluation and comparison
    y_target = target_f(x_target)
    return ((x_train,y_train),(x_valid,y_valid),(x_target,y_target))

m = 2; b = 1  #target parameters of f(x) = m*x + b
def linear(x): return m*x + b
aa,bb,cc,dd=4.,-3.,-2.,3. #target parameters of f(x) = a + b*x + c*x**2 + d*x**3
def polynomial(x): return aa + bb*x + cc*x**2 + dd*x**3

def reg_plot(x,y,x_target,y_target,ylab): #plot training and target dataset
    plt.plot(x_target,y_target, label='target')
    plt.scatter(x,y, color='r',s=10, label=ylab+' data')
    plt.legend(loc="best")
    plt.grid(True); plt.show()

# %%
lin_data=data_gen(100,10,linear,0)
xtg=np.random.uniform(-1, 1, 80)  #x_target only for the graph
xtg.sort()
ytg=linear(xtg)

plt.figure(figsize=(5,3))
reg_plot(lin_data[1][0],lin_data[1][1],xtg,ytg,'validation')

# %% [markdown]
# In questo caso molto semplice è sufficiente una rete composta dai soli layer di input e di output, entrambi a singolo neurone. Infatti se come funzione di attivazione viene scelta l'identità (opzione di default), allora, come spiegato all'inizio, l'output dell'unico neurone mappante presente, e quindi della rete, sarà proprio del tipo $g(x)=p_1 x + p_2$, con $p_1$ e $p_2$ unici parametri da ottimizzare nella fase di training. Con un training efficace questa rete, per quanto essenziale, è del tutto in grado di riprodurre completamente la funzione target.

# %%
def composeNN_singleN(data,bsize,epochs,iffirst):
    #compose the NN model
    model = tf.keras.Sequential()
    model.add(Dense(1, input_shape=(1,)))
    #compile the model choosing optimizer, loss and metrics objects
    model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
    #get a summary of our composed model
    if(iffirst): model.summary(); print(); print()
    
    # fit the model using training dataset
    # report training progress against validation data
    history = model.fit(x=data[0][0],y=data[0][1], 
          batch_size=bsize, epochs=epochs,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(data[1][0],data[1][1]))
    return model,history

# %%
lin1,lin1_hist = composeNN_singleN(lin_data,32,30,True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
#
#
# Epoch 1/30
# 4/4 [==============================] - 1s 126ms/step - loss: 1.2334 - mse: 1.2334 - val_loss: 0.7041 - val_mse: 0.7041
# Epoch 2/30
# 4/4 [==============================] - 0s 33ms/step - loss: 1.0806 - mse: 1.0806 - val_loss: 0.6209 - val_mse: 0.6209
# Epoch 3/30
# 4/4 [==============================] - 0s 36ms/step - loss: 0.9732 - mse: 0.9732 - val_loss: 0.5406 - val_mse: 0.5406
# Epoch 4/30
# 4/4 [==============================] - 0s 18ms/step - loss: 0.8664 - mse: 0.8664 - val_loss: 0.4718 - val_mse: 0.4718
# Epoch 5/30
# 4/4 [==============================] - 0s 18ms/step - loss: 0.7752 - mse: 0.7752 - val_loss: 0.4201 - val_mse: 0.4201
# Epoch 6/30
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7038 - mse: 0.7038 - val_loss: 0.3772 - val_mse: 0.3772
# Epoch 7/30
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6430 - mse: 0.6430 - val_loss: 0.3322 - val_mse: 0.3322
# Epoch 8/30
# 4/4 [==============================] - 0s 14ms/step - loss: 0.5778 - mse: 0.5778 - val_loss: 0.2975 - val_mse: 0.2975
# Epoch 9/30
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5263 - mse: 0.5263 - val_loss: 0.2657 - val_mse: 0.2657
# Epoch 10/30
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4784 - mse: 0.4784 - val_loss: 0.2345 - val_mse: 0.2345
# Epoch 11/30
# 4/4 [==============================] - 0s 29ms/step - loss: 0.4303 - mse: 0.4303 - val_loss: 0.2120 - val_mse: 0.2120
# Epoch 12/30
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3934 - mse: 0.3934 - val_loss: 0.1896 - val_mse: 0.1896
# Epoch 13/30
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3574 - mse: 0.3574 - val_loss: 0.1726 - val_mse: 0.1726
# Epoch 14/30
# 4/4 [==============================] - 0s 19ms/step - loss: 0.3281 - mse: 0.3281 - val_loss: 0.1575 - val_mse: 0.1575
# Epoch 15/30
# 4/4 [==============================] - 0s 21ms/step - loss: 0.3024 - mse: 0.3024 - val_loss: 0.1455 - val_mse: 0.1455
# Epoch 16/30
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2812 - mse: 0.2812 - val_loss: 0.1342 - val_mse: 0.1342
# Epoch 17/30
# 4/4 [==============================] - 0s 17ms/step - loss: 0.2608 - mse: 0.2608 - val_loss: 0.1239 - val_mse: 0.1239
# Epoch 18/30
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2424 - mse: 0.2424 - val_loss: 0.1156 - val_mse: 0.1156
# Epoch 19/30
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2265 - mse: 0.2265 - val_loss: 0.1058 - val_mse: 0.1058
# Epoch 20/30
# 4/4 [==============================] - 0s 16ms/step - loss: 0.2079 - mse: 0.2079 - val_loss: 0.0976 - val_mse: 0.0976
# Epoch 21/30
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1921 - mse: 0.1921 - val_loss: 0.0921 - val_mse: 0.0921
# Epoch 22/30
# 4/4 [==============================] - 0s 42ms/step - loss: 0.1809 - mse: 0.1809 - val_loss: 0.0857 - val_mse: 0.0857
# Epoch 23/30
# 4/4 [==============================] - 0s 23ms/step - loss: 0.1683 - mse: 0.1683 - val_loss: 0.0811 - val_mse: 0.0811
# Epoch 24/30
# 4/4 [==============================] - 0s 25ms/step - loss: 0.1590 - mse: 0.1590 - val_loss: 0.0763 - val_mse: 0.0763
# Epoch 25/30
# 4/4 [==============================] - 0s 37ms/step - loss: 0.1492 - mse: 0.1492 - val_loss: 0.0718 - val_mse: 0.0718
# Epoch 26/30
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1400 - mse: 0.1400 - val_loss: 0.0671 - val_mse: 0.0671
# Epoch 27/30
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1306 - mse: 0.1306 - val_loss: 0.0632 - val_mse: 0.0632
# Epoch 28/30
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1223 - mse: 0.1223 - val_loss: 0.0596 - val_mse: 0.0596
# Epoch 29/30
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1145 - mse: 0.1145 - val_loss: 0.0569 - val_mse: 0.0569
# Epoch 30/30
# 4/4 [==============================] - 0s 17ms/step - loss: 0.1088 - mse: 0.1088 - val_loss: 0.0541 - val_mse: 0.0541

# %% [markdown]
# Nell'output della funzione <font face="Courier">summary</font> il layer di input, privo di parametri liberi e di dimesione vincolata dalla forma stessa dei dati di input, è sottointeso. Avendo inoltre scelto di utilizzare un unico layer aggiuntivo questo non può che avere dimensione $1$, perché deve rispettare invece la dimensionalità dei dati di output. In altre parole il dataset ha già di suo una certa struttura I/O che non può che essere riprodotta. Il numero totale dei parametri della rete è giustamente $2$, come anticipato più sopra (un neurone, un bias e un input col suo relativo peso).

# %% [markdown]
# In questo caso molto semplice il successo del fit può essere valutato guardando direttamente i pesi ottimizzati, che dovrebbero riprodurre il più possibile coefficiente angolare e intercetta della funzione target.

# %%
print(lin1.get_weights())   # return weights
# Out:
# [array([[1.4662026]], dtype=float32), array([0.87431043], dtype=float32)]

# %% [markdown]
# Già da qui si vede che il risultato non è per nulla soddisfacente. Come si vede più sotto la ragione principale è la scarsità di dati messi a disposizione della rete più che al numero di epoche scelto per il training o per la struttura scelta per la rete stessa.

# %%
def evaluate(model,data,bsize):
    tit=('validation data','the exact curve')

    for j in range(2):
        print('evaluate model with '+tit[j]+':'); print()
        score = model.evaluate(data[j+1][0],data[j+1][1], batch_size=bsize, verbose=1)
        # print performance
        print(); print('Test loss:', score[0])
        print('Test accuracy:', score[1])
 
        if(j==0): print(); print('---------------------------------'); print()

# %%
evaluate(lin1,lin_data,32)
# Out:
# evaluate model with validation data:
#
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0541 - mse: 0.0541
#
# Test loss: 0.05410126969218254
# Test accuracy: 0.05410126969218254
#
# ---------------------------------
#
# evaluate model with the exact curve:
#
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0541 - mse: 0.0541
#
# Test loss: 0.05410126969218254
# Test accuracy: 0.05410126969218254

# %% [markdown]
# Qui sopra ho riportato gli errori commessi alla fine dell'ottimizzazione, utilizzando sia i dati di validazione sia quelli generati in maniera esatta dal modello. Le ascisse dei due set di dati sono uguali, e quindi in assenza di errore gaussiano (come in questo caso), le due istanze dell'errore commesso non possono che coincidere.

# %%
def losses(history,title):
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title(title)
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.grid(True)
    plt.legend(['Train', 'Test'], loc='best')

def loss_fit(history,title,x,y,x_target,y_target,ylab):
    plt.figure(figsize=(15,4))

    plt.subplot(1,2,1)
    losses(history,title)

    plt.subplot(1,2,2)
    reg_plot(x,y,xtg,ytg,ylab)

# %% [markdown]
# I due grafici sotto riassumono completamente i risultati riportando da un lato l'andamento degli errori di training e di validazione durante l'ottimizzazione della rete e dall'altro il confronto tra il modello esatto di partenza e il risultato finale del fit della macchina, ottenuto facendo predire alla rete il valore di output per una serie di dati totalmente nuovi e generati appositamente.

# %%
x_pred = np.random.uniform(-1, 1, 100)
loss_fit(lin1_hist,'Model loss',x_pred,lin1.predict(x_pred),lin_data[2][0],lin_data[2][1],'predicted')

# %% [markdown]
# Il grafico a destra mostra in maniera evidente il fallimento del training attuale della rete, come già anticipato dai valori ottenuti per i suoi parametri.
#
# A sinistra vediamo che entrambi gli errori continuano a diminuire al crescere del numero di epoche. Questo è buono: per esempio un eventuale aumento da una certa epoca in poi di $E_{out}$ avrebbe potuto indicare un overfitting, condizione in cui la rete è troppo complessa per il numero di dati a disposizione ed inizia a fittarne anche il rumore. Qui chiaramente questa è un'eventualità del tutto impossibile, sia perchè i dati sono ora privi di rumore sia perché, più in generale, la macchina ha una struttura ovviamente troppo semplice. D'altra parte la diminuzione della funzione costo non è del tutto esaurita con l'epoca $N_{epochs}=30$, per cui una strada che si potrebbe seguire per migliorare il risultato è proprio quella di aumentare le epoche della fase di training.

# %% [markdown]
# Questo è il primo tentativo che ho fatto. Ho usato la stessa NN e l'ho trainata e validata con gli stessi dati, ma questa volta $N_{epochs}=100$.

# %%
lin2,lin2_hist = composeNN_singleN(lin_data,32,100,False)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 69ms/step - loss: 1.3515 - mse: 1.3515 - val_loss: 0.7399 - val_mse: 0.7399
# Epoch 2/100
# 4/4 [==============================] - 0s 25ms/step - loss: 1.2068 - mse: 1.2068 - val_loss: 0.6529 - val_mse: 0.6529
# Epoch 3/100
# 4/4 [==============================] - 0s 20ms/step - loss: 1.
100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.1160 - mse: 0.1160 - val_loss: 0.0584 - val_mse: 0.0584
# Epoch 34/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.1090 - mse: 0.1090 - val_loss: 0.0558 - val_mse: 0.0558
# Epoch 35/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.1037 - mse: 0.1037 - val_loss: 0.0532 - val_mse: 0.0532
# Epoch 36/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0988 - mse: 0.0988 - val_loss: 0.0502 - val_mse: 0.0502
# Epoch 37/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0927 - mse: 0.0927 - val_loss: 0.0476 - val_mse: 0.0476
# Epoch 38/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0877 - mse: 0.0877 - val_loss: 0.0455 - val_mse: 0.0455
# Epoch 39/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0829 - mse: 0.0829 - val_loss: 0.0430 - val_mse: 0.0430
# Epoch 40/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0781 - mse: 0.0781 - val_loss: 0.0412 - val_mse: 0.0412
# Epoch 41/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0745 - mse: 0.0745 - val_loss: 0.0389 - val_mse: 0.0389
# Epoch 42/100
# 4/4 [==============================] - 0s 33ms/step - loss: 0.0702 - mse: 0.0702 - val_loss: 0.0369 - val_mse: 0.0369
# Epoch 43/100
# 4/4 [==============================] - 0s 37ms/step - loss: 0.0660 - mse: 0.0660 - val_loss: 0.0352 - val_mse: 0.0352
# Epoch 44/100
# 4/4 [==============================] - 0s 51ms/step - loss: 0.0628 - mse: 0.0628 - val_loss: 0.0336 - val_mse: 0.0336
# Epoch 45/100
# 4/4 [==============================] - 0s 66ms/step - loss: 0.0597 - mse: 0.0597 - val_loss: 0.0318 - val_mse: 0.0318
# Epoch 46/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0561 - mse: 0.0561 - val_loss: 0.0304 - val_mse: 0.0304
# Epoch 47/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0532 - mse: 0.0532 - val_loss: 0.0288 - val_mse: 0.0288
# Epoch 48/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0499 - mse: 0.0499 - val_loss: 0.0271 - val_mse: 0.0271
# Epoch 49/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0472 - mse: 0.0472 - val_loss: 0.0257 - val_mse: 0.0257
# Epoch 50/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0446 - mse: 0.0446 - val_loss: 0.0244 - val_mse: 0.0244
# Epoch 51/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0424 - mse: 0.0424 - val_loss: 0.0232 - val_mse: 0.0232
# Epoch 52/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0403 - mse: 0.0403 - val_loss: 0.0221 - val_mse: 0.0221
# Epoch 53/100
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0384 - mse: 0.0384 - val_loss: 0.0211 - val_mse: 0.0211
# Epoch 54/100
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0363 - mse: 0.0363 - val_loss: 0.0198 - val_mse: 0.0198
# Epoch 55/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0342 - mse: 0.0342 - val_loss: 0.0187 - val_mse: 0.0187
# Epoch 56/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0325 - mse: 0.0325 - val_loss: 0.0177 - val_mse: 0.0177
# Epoch 57/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0309 - mse: 0.0309 - val_loss: 0.0168 - val_mse: 0.0168
# Epoch 58/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0292 - mse: 0.0292 - val_loss: 0.0159 - val_mse: 0.0159
# Epoch 59/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0277 - mse: 0.0277 - val_loss: 0.0152 - val_mse: 0.0152
# Epoch 60/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0263 - mse: 0.0263 - val_loss: 0.0145 - val_mse: 0.0145
# Epoch 61/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0252 - mse: 0.0252 - val_loss: 0.0139 - val_mse: 0.0139
# Epoch 62/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0238 - mse: 0.0238 - val_loss: 0.0130 - val_mse: 0.0130
# Epoch 63/100
# 4/4 [==============================] - 0s 42ms/step - loss: 0.0225 - mse: 0.0225 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 64/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0213 - mse: 0.0213 - val_loss: 0.0117 - val_mse: 0.0117
# Epoch 65/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0202 - mse: 0.0202 - val_loss: 0.0111 - val_mse: 0.0111
# Epoch 66/100
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0105 - val_mse: 0.0105
# Epoch 67/100
# 4/4 [==============================] - 0s 76ms/step - loss: 0.0176 - mse: 0.0176 - val_loss: 0.0099 - val_mse: 0.0099
# Epoch 68/100
# 4/4 [==============================] - 0s 43ms/step - loss: 0.0167 - mse: 0.0167 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 69/100
# 4/4 [==============================] - 1s 148ms/step - loss: 0.0158 - mse: 0.0158 - val_loss: 0.0089 - val_mse: 0.0089
# Epoch 70/100
# 4/4 [==============================] - 1s 188ms/step - loss: 0.0150 - mse: 0.0150 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 71/100
# 4/4 [==============================] - 0s 89ms/step - loss: 0.0142 - mse: 0.0142 - val_loss: 0.0080 - val_mse: 0.0080
# Epoch 72/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0134 - mse: 0.0134 - val_loss: 0.0076 - val_mse: 0.0076
# Epoch 73/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0073 - val_mse: 0.0073
# Epoch 74/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0069 - val_mse: 0.0069
# Epoch 75/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 76/100
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0061 - val_mse: 0.0061
# Epoch 77/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0059 - val_mse: 0.0059
# Epoch 78/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0055 - val_mse: 0.0055
# Epoch 79/100
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0052 - val_mse: 0.0052
# Epoch 80/100
# 4/4 [==============================] - 0s 40ms/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 81/100
# 4/4 [==============================] - 0s 44ms/step - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0047 - val_mse: 0.0047
# Epoch 82/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0045 - val_mse: 0.0045
# Epoch 83/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0043 - val_mse: 0.0043
# Epoch 84/100
# 4/4 [==============================] - 0s 76ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0041 - val_mse: 0.0041
# Epoch 85/100
# 4/4 [==============================] - 0s 36ms/step - loss: 0.0066 - mse: 0.0066 - val_loss: 0.0039 - val_mse: 0.0039
# Epoch 86/100
# 4/4 [==============================] - 0s 34ms/step - loss: 0.0063 - mse: 0.0063 - val_loss: 0.0037 - val_mse: 0.0037
# Epoch 87/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0035 - val_mse: 0.0035
# Epoch 88/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0033 - val_mse: 0.0033
# Epoch 89/100
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0053 - mse: 0.0053 - val_loss: 0.0031 - val_mse: 0.0031
# Epoch 90/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0029 - val_mse: 0.0029
# Epoch 91/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0027 - val_mse: 0.0027
# Epoch 92/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0026 - val_mse: 0.0026
# Epoch 93/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0024 - val_mse: 0.0024
# Epoch 94/100
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 95/100
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0022 - val_mse: 0.0022
# Epoch 96/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0021 - val_mse: 0.0021
# Epoch 97/100
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0035 - mse: 0.0035 - val_loss: 0.0020 - val_mse: 0.0020
# Epoch 98/100
# 4/4 [==============================] - 0s 20ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 99/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 100/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0017 - val_mse: 0.0017

# %%
print(lin2.get_weights())   # return weights
# Out:
# [array([[1.908357]], dtype=float32), array([0.9909539], dtype=float32)]

# %%
evaluate(lin2,lin_data,32)
# Out:
# evaluate model with validation data:
#
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0017 - mse: 0.0017
#
# Test loss: 0.001686216564849019
# Test accuracy: 0.001686216564849019
#
# ---------------------------------
#
# evaluate model with the exact curve:
#
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0017 - mse: 0.0017
#
# Test loss: 0.001686216564849019
# Test accuracy: 0.001686216564849019

# %%
x_pred = np.random.uniform(-1, 1, 100)
loss_fit(lin2_hist,'Model loss',x_pred,lin2.predict(x_pred),lin_data[2][0],lin_data[2][1],'predicted')

# %% [markdown]
# La situazione è migliorata sensibilmente, ma ancora non è soddisfacente. Se non si avesse la possibilità di aumentare il numero di dati di training si potrebbe provare ad aumentare ancora il numero totale di epoche, ma il rate di diminuzione degli errori diminuisce sempre di più procedendo nel processo di ottimizzazione. La cosa migliore da fare è decisamente aumentare il numero di dati di training forniti alla rete.

# %% [markdown]
# I risultati che seguono sono ottenuti con $N_{epochs}=30$, $N_{train}=1000$ e $N_{valid}=100$. I dati sono generati ancora senza incertezza.

# %%
lin_newdata=data_gen(1000,100,linear,0)
plt.figure(figsize=(5,3))
reg_plot(lin_newdata[1][0],lin_newdata[1][1],xtg,ytg,'validation')

# %%
lin3,lin3_hist = composeNN_singleN(lin_newdata,32,30,False)
# Out:
# Epoch 1/30
# 32/32 [==============================] - 0s 5ms/step - loss: 3.4123 - mse: 3.4123 - val_loss: 2.5789 - val_mse: 2.5789
# Epoch 2/30
# 32/32 [==============================] - 0s 3ms/step - loss: 1.9220 - mse: 1.9220 - val_loss: 1.5223 - val_mse: 1.5223
# Epoch 3/30
# 32/32 [==============================] - 0s 2ms/step - loss: 1.1596 - mse: 1.1596 - val_loss: 0.9255 - val_mse: 0.9255
# Epoch 4/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.7168 - mse: 0.7168 - val_loss: 0.5791 - val_mse: 0.5791
# Epoch 5/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4523 - mse: 0.4523 - val_loss: 0.3668 - val_mse: 0.3668
# Epoch 6/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2874 - mse: 0.2874 - val_loss: 0.2312 - val_mse: 0.2312
# Epoch 7/30
# 32/32 [==============================] - 0s 14ms/step - loss: 0.1818 - mse: 0.1818 - val_loss: 0.1471 - val_mse: 0.1471
# Epoch 8/30
# 32/32 [==============================] - 0s 13ms/step - loss: 0.1159 - mse: 0.1159 - val_loss: 0.0938 - val_mse: 0.0938
# Epoch 9/30
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0739 - mse: 0.0739 - val_loss: 0.0597 - val_mse: 0.0597
# Epoch 10/30
# 32/32 [==============================] - 0s 12ms/step - loss: 0.0471 - mse: 0.0471 - val_loss: 0.0380 - val_mse: 0.0380
# Epoch 11/30
# 32/32 [==============================] - 0s 15ms/step - loss: 0.0300 - mse: 0.0300 - val_loss: 0.0243 - val_mse: 0.0243
# Epoch 12/30
# 32/32 [==============================] - 1s 17ms/step - loss: 0.0192 - mse: 0.0192 - val_loss: 0.0155 - val_mse: 0.0155
# Epoch 13/30
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0098 - val_mse: 0.0098
# Epoch 14/30
# 32/32 [==============================] - 0s 10ms/step - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 15/30
# 32/32 [==============================] - 0s 10ms/step - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0040 - val_mse: 0.0040
# Epoch 16/30
# 32/32 [==============================] - 0s 9ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0025 - val_mse: 0.0025
# Epoch 17/30
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 18/30
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 19/30
# 32/32 [==============================] - 0s 8ms/step - loss: 8.0938e-04 - mse: 8.0938e-04 - val_loss: 6.5436e-04 - val_mse: 6.5436e-04
# Epoch 20/30
# 32/32 [==============================] - 0s 5ms/step - loss: 5.1635e-04 - mse: 5.1635e-04 - val_loss: 4.1536e-04 - val_mse: 4.1536e-04
# Epoch 21/30
# 32/32 [==============================] - 0s 4ms/step - loss: 3.2785e-04 - mse: 3.2785e-04 - val_loss: 2.6544e-04 - val_mse: 2.6544e-04
# Epoch 22/30
# 32/32 [==============================] - 0s 5ms/step - loss: 2.0956e-04 - mse: 2.0956e-04 - val_loss: 1.6951e-04 - val_mse: 1.6951e-04
# Epoch 23/30
# 32/32 [==============================] - 0s 7ms/step - loss: 1.3378e-04 - mse: 1.3378e-04 - val_loss: 1.0846e-04 - val_mse: 1.0846e-04
# Epoch 24/30
# 32/32 [==============================] - 0s 7ms/step - loss: 8.5538e-05 - mse: 8.5538e-05 - val_loss: 6.8789e-05 - val_mse: 6.8789e-05
# Epoch 25/30
# 32/32 [==============================] - 0s 6ms/step - loss: 5.4292e-05 - mse: 5.4292e-05 - val_loss: 4.3880e-05 - val_mse: 4.3880e-05
# Epoch 26/30
# 32/32 [==============================] - 0s 4ms/step - loss: 3.4597e-05 - mse: 3.4597e-05 - val_loss: 2.7935e-05 - val_mse: 2.7935e-05
# Epoch 27/30
# 32/32 [==============================] - 0s 5ms/step - loss: 2.2043e-05 - mse: 2.2043e-05 - val_loss: 1.7708e-05 - val_mse: 1.7708e-05
# Epoch 28/30
# 32/32 [==============================] - 0s 5ms/step - loss: 1.3969e-05 - mse: 1.3969e-05 - val_loss: 1.1263e-05 - val_mse: 1.1263e-05
# Epoch 29/30
# 32/32 [==============================] - 0s 2ms/step - loss: 8.8898e-06 - mse: 8.8898e-06 - val_loss: 7.2099e-06 - val_mse: 7.2099e-06
# Epoch 30/30
# 32/32 [==============================] - 0s 2ms/step - loss: 5.6893e-06 - mse: 5.6893e-06 - val_loss: 4.5709e-06 - val_mse: 4.5709e-06

# %%
print(lin3.get_weights())   # return weights
# Out:
# [array([[1.9964515]], dtype=float32), array([1.0001117], dtype=float32)]

# %%
evaluate(lin3,lin_newdata,32)
# Out:
# evaluate model with validation data:
#
# 4/4 [==============================] - 0s 1ms/step - loss: 4.5709e-06 - mse: 4.5709e-06
#
# Test loss: 4.570918008539593e-06
# Test accuracy: 4.570918008539593e-06
#
# ---------------------------------
#
# evaluate model with the exact curve:
#
# 4/4 [==============================] - 0s 2ms/step - loss: 4.5709e-06 - mse: 4.5709e-06
#
# Test loss: 4.570918008539593e-06
# Test accuracy: 4.570918008539593e-06

# %%
x_pred = np.random.uniform(-1, 1, 100)
loss_fit(lin3_hist,'Model loss',x_pred,lin3.predict(x_pred),lin_newdata[2][0],lin_newdata[2][1],'predicted')

# %% [markdown]
# La convergenza ora è molto buona. Non solo $30$ epoche sono state sufficienti, ma si potrebbero anche ridurre a circa la metà. Per un funzionamento ottimale della NN è molto più utile fornire molti dati piuttosto che aumentare la durata dell'ottimizzazione. D'altra parte uno dei concetti fondamentali alla base del Machine Learning è che una rete neurale per poter funzionare bene deve prima aver fatto esperienza su un numero di dati sufficiente.

# %% [markdown]
# Mantenendo lo stesso numero di dati e di epoche ho infine provato a fittare con la stessa rete dei dati generati con un rumore gaussiano con $\sigma=1$.

# %%
lin_dataerr=data_gen(1000,100,linear,1)
plt.figure(figsize=(5,3))
reg_plot(lin_dataerr[1][0],lin_dataerr[1][1],xtg,ytg,'validation')

# %%
lin4,lin4_hist = composeNN_singleN(lin_dataerr,32,30,False)
# Out:
# Epoch 1/30
# 32/32 [==============================] - 1s 22ms/step - loss: 5.1500 - mse: 5.1500 - val_loss: 4.7263 - val_mse: 4.7263
# Epoch 2/30
# 32/32 [==============================] - 0s 10ms/step - loss: 3.5951 - mse: 3.5951 - val_loss: 3.4216 - val_mse: 3.4216
# Epoch 3/30
# 32/32 [==============================] - 0s 12ms/step - loss: 2.6774 - mse: 2.6774 - val_loss: 2.6122 - val_mse: 2.6122
# Epoch 4/30
# 32/32 [==============================] - 0s 13ms/step - loss: 2.1027 - mse: 2.1027 - val_loss: 2.0911 - val_mse: 2.0911
# Epoch 5/30
# 32/32 [==============================] - 0s 14ms/step - loss: 1.7303 - mse: 1.7303 - val_loss: 1.7534 - val_mse: 1.7534
# Epoch 6/30
# 32/32 [==============================] - 1s 22ms/step - loss: 1.4915 - mse: 1.4915 - val_loss: 1.5226 - val_mse: 1.5226
# Epoch 7/30
# 32/32 [==============================] - 0s 12ms/step - loss: 1.3334 - mse: 1.3334 - val_loss: 1.3619 - val_mse: 1.3619
# Epoch 8/30
# 32/32 [==============================] - 0s 9ms/step - loss: 1.2288 - mse: 1.2288 - val_loss: 1.2614 - val_mse: 1.2614
# Epoch 9/30
# 32/32 [==============================] - 0s 10ms/step - loss: 1.1610 - mse: 1.1610 - val_loss: 1.1924 - val_mse: 1.1924
# Epoch 10/30
# 32/32 [==============================] - 0s 6ms/step - loss: 1.1183 - mse: 1.1183 - val_loss: 1.1429 - val_mse: 1.1429
# Epoch 11/30
# 32/32 [==============================] - 0s 5ms/step - loss: 1.0894 - mse: 1.0894 - val_loss: 1.1022 - val_mse: 1.1022
# Epoch 12/30
# 32/32 [==============================] - 0s 6ms/step - loss: 1.0695 - mse: 1.0695 - val_loss: 1.0693 - val_mse: 1.0693
# Epoch 13/30
# 32/32 [==============================] - 0s 5ms/step - loss: 1.0560 - mse: 1.0560 - val_loss: 1.0554 - val_mse: 1.0554
# Epoch 14/30
# 32/32 [==============================] - 0s 6ms/step - loss: 1.0490 - mse: 1.0490 - val_loss: 1.0404 - val_mse: 1.0404
# Epoch 15/30
# 32/32 [==============================] - 0s 7ms/step - loss: 1.0436 - mse: 1.0436 - val_loss: 1.0304 - val_mse: 1.0304
# Epoch 16/30
# 32/32 [==============================] - 0s 6ms/step - loss: 1.0407 - mse: 1.0407 - val_loss: 1.0200 - val_mse: 1.0200
# Epoch 17/30
# 32/32 [==============================] - 0s 6ms/step - loss: 1.0384 - mse: 1.0384 - val_loss: 1.0150 - val_mse: 1.0150
# Epoch 18/30
# 32/32 [==============================] - 0s 6ms/step - loss: 1.0372 - mse: 1.0372 - val_loss: 1.0129 - val_mse: 1.0129
# Epoch 19/30
# 32/32 [==============================] - 0s 6ms/step - loss: 1.0362 - mse: 1.0362 - val_loss: 1.0097 - val_mse: 1.0097
# Epoch 20/30
# 32/32 [==============================] - 0s 4ms/step - loss: 1.0358 - mse: 1.0358 - val_loss: 1.0125 - val_mse: 1.0125
# Epoch 21/30
# 32/32 [==============================] - 0s 5ms/step - loss: 1.0353 - mse: 1.0353 - val_loss: 1.0099 - val_mse: 1.0099
# Epoch 22/30
# 32/32 [==============================] - 0s 6ms/step - loss: 1.0348 - mse: 1.0348 - val_loss: 1.0069 - val_mse: 1.0069
# Epoch 23/30
# 32/32 [==============================] - 0s 7ms/step - loss: 1.0346 - mse: 1.0346 - val_loss: 1.0053 - val_mse: 1.0053
# Epoch 24/30
# 32/32 [==============================] - 0s 5ms/step - loss: 1.0346 - mse: 1.0346 - val_loss: 1.0021 - val_mse: 1.0021
# Epoch 25/30
# 32/32 [==============================] - 0s 5ms/step - loss: 1.0344 - mse: 1.0344 - val_loss: 1.0028 - val_mse: 1.0028
# Epoch 26/30
# 32/32 [==============================] - 0s 5ms/step - loss: 1.0343 - mse: 1.0343 - val_loss: 1.0055 - val_mse: 1.0055
# Epoch 27/30
# 32/32 [==============================] - 0s 5ms/step - loss: 1.0345 - mse: 1.0345 - val_loss: 1.0020 - val_mse: 1.0020
# Epoch 28/30
# 32/32 [==============================] - 0s 3ms/step - loss: 1.0342 - mse: 1.0342 - val_loss: 1.0023 - val_mse: 1.0023
# Epoch 29/30
# 32/32 [==============================] - 0s 3ms/step - loss: 1.0344 - mse: 1.0344 - val_loss: 1.0003 - val_mse: 1.0003
# Epoch 30/30
# 32/32 [==============================] - 0s 10ms/step - loss: 1.0343 - mse: 1.0343 - val_loss: 0.9980 - val_mse: 0.9980

# %%
print(lin4.get_weights())   # return weights
# Out:
# [array([[2.0107584]], dtype=float32), array([0.9951954], dtype=float32)]

# %%
evaluate(lin4,lin_dataerr,32)
# Out:
# evaluate model with validation data:
#
# 4/4 [==============================] - 0s 6ms/step - loss: 0.9980 - mse: 0.9980
#
# Test loss: 0.9980250000953674
# Test accuracy: 0.9980250000953674
#
# ---------------------------------
#
# evaluate model with the exact curve:
#
# 4/4 [==============================] - 0s 9ms/step - loss: 6.0739e-05 - mse: 6.0739e-05
#
# Test loss: 6.0738773754565045e-05
# Test accuracy: 6.0738773754565045e-05

# %% [markdown]
# Gli errori qui sono più piccoli nel caso del confronto coi dati privi di errore. Questo è un ottimo segno, perché indica che la rete ha completato la regressione riuscendo anche in qualche modo a ripulire i dati di train dal rumore e a riconoscere quindi la vera funzione target, come si vede anche nel grafico finale.

# %%
x_pred = np.random.uniform(-1, 1, 100)
loss_fit(lin4_hist,'Model loss',x_pred,lin4.predict(x_pred),lin_dataerr[2][0],lin_dataerr[2][1],'predicted')

# %% [markdown]
# Anche qui il grafico delle loss suggerisce che il numero di epoche potrebbe essere in parte ridotto. Il più alto valore delle funzioni costo è dovuto all'introduzione nei dati dell'errore statistico.

# %% [markdown]
# ### Esercizio 11.2
#
# Passo quindi a fittare dati generati secondo la funzione polinomiale
#
# $$ f(x)=4-3x-2x^2+3x^3 $$
#
# nell'intervallo $[-1,1]$. I dati sono soggetti ad un errore gaussiano con $\sigma=0.3$. Per una migliore efficienza delle NNs il numero di punti di training è stato aumentato a $N_{train}=10^4$.
#
# In questo esercizio provo ad utilizzare differenti strutture, funzioni di attivazione, funzioni costo e ottimizzatori per costruire le reti neurali e a vedere come cambiano i risultati del fit in funzione di questo. Con le NN ottimizzate proverò a predirre gli output corrispondenti a nuovi dati generati sia all'interno che all'esterno dell'intervallo di training.

# %%
poly_data=data_gen(int(1e4),1000,polynomial,0.3)
xtg=np.random.uniform(-2, 2, 500)  #x_target only for the graph
xtg.sort()
ytg=polynomial(xtg)

plt.figure(figsize=(5,3))
reg_plot(poly_data[1][0],poly_data[1][1],xtg,ytg,'validation')

# %% [markdown]
# Anche prima di effettuare test è chiaro che la funzione risposta dei neuroni della rete non può più essere lasciata lineare, perché una NN così costruita non potrebbe che produrre output lineari. Farò comunque una prova con un numero relativamente alto di layer e di neuroni per layer per mostrare questa cosa.\
# Contemporaneamente testerò tre reti con un numero simile di parametri in cui provo rispettivamente ad aumentare il numero di neuroni di un unico layer interno, ad aumentare il numero di layer a singolo neurone e infine a fare una combinazione di entrambe le operazioni.

# %%
def compileNN(models,optimizer,loss,met):   #compile the model choosing optimizer, loss and metrics objects
    for mod in models:
        mod.compile(optimizer=optimizer, loss=loss, metrics=[met])
        mod.summary(); print()    

def history(models,data,bsize,epochs):    # fit the model using training dataset
    if type(epochs) is int: ep=[epochs for i in range(len(models))]
    else: ep=epochs
    return [models[i].fit(x=data[0][0],y=data[0][1], 
          batch_size=bsize, epochs=ep[i], shuffle=True,
          validation_data=(data[1][0],data[1][1]))
          for i in range(len(models))]

# %%
#linear activation function
lin = tf.keras.Sequential()
lin.add(Dense(20,input_shape=(1,)))
for i in range(4): lin.add(Dense(15))
lin.add(Dense(1))

#more neurons
moreN = tf.keras.Sequential()
moreN.add(Dense(12,input_shape=(1,),activation='selu'))
moreN.add(Dense(1,activation='selu'))

#more layers
moreL = tf.keras.Sequential()
moreL.add(Dense(1,input_shape=(1,),activation='selu'))
for i in range(17): moreL.add(Dense(1,activation='selu'))

#more neurons and layers
poly1 = tf.keras.Sequential()
#for i in range(4): poly1.add(Dense(3,input_shape=(1,),activation='selu'))
#for i in range(4): poly1.add(Dense(4-i,input_shape=(1,),activation='selu'))
for i in range(4): poly1.add(Dense(1+i,input_shape=(1,),activation='selu'))
poly1.add(Dense(1,activation='selu'))

models1=[lin,moreN,moreL,poly1]
compileNN(models1,SGD(),'mse','mse')
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 20)                40
# _________________________________________________________________
# dense_5 (Dense)              (None, 15)                315
# _________________________________________________________________
# dense_6 (Dense)              (None, 15)                240
# _________________________________________________________________
# dense_7 (Dense)              (None, 15)                240
# _________________________________________________________________
# dense_8 (Dense)              (None, 15)                240
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 16
# =================================================================
# Total params: 1,091
# Trainable params: 1,091
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 12)                24
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 13
# =================================================================
# Total params: 37
# Trainable params: 37
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_21 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_22 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_23 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_25 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_26 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_27 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_29 (Dense)             (None, 1)                 2
# =================================================================
# Total params: 36
# Trainable params: 36
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_30 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_31 (Dense)             (None, 2)                 4
# _________________________________________________________________
# dense_32 (Dense)             (None, 3)                 9
# _________________________________________________________________
# dense_33 (Dense)             (None, 4)                 16
# _________________________________________________________________
# dense_34 (Dense)             (None, 1)                 5
# =================================================================
# Total params: 36
# Trainable params: 36
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist1 = history(models1,poly_data,150,15)
# Out:
# Epoch 1/15
# 67/67 [==============================] - 1s 16ms/step - loss: 1.1260 - mse: 1.1260 - val_loss: 0.6376 - val_mse: 0.6376
# Epoch 2/15
# 67/67 [==============================] - 1s 8ms/step - loss: 0.6754 - mse: 0.6754 - val_loss: 0.7015 - val_mse: 0.7015
# Epoch 3/15
# 67/67 [==============================] - 0s 7ms/step - loss: 0.6731 - mse: 0.6731 - val_loss: 0.6315 - val_mse: 0.6315
# Epoch 4/15
# 67/67 [==============================] - 1s 9ms/step - loss: 0.6728 - mse: 0.6728 - val_loss: 0.6625 - val_mse: 0.6625
# Epoch 5/15
# 67/67 [==============================] - 1s 8ms/step - loss: 0.6714 - mse: 0.6714 - val_loss: 0.6408 - val_mse: 0.6408
# Epoch 6/15
# 67/67 [==============================] - 1s 9ms/step - loss: 0.6747 - mse: 0.6747 - val_loss: 0.6990 - val_mse: 0.6990
# Epoch 7/15
# 67/67 [==============================] - 0s 7ms/step - loss: 0.6730 - mse: 0.6730 - val_loss: 0.6317 - val_mse: 0.6317
# Epoch 8/15
# 67/67 [==============================] - 0s 6ms/step - loss: 0.6710 - mse: 0.6710 - val_loss: 0.6318 - val_mse: 0.6318
# Epoch 9/15
# 67/67 [==============================] - 0s 6ms/step - loss: 0.6715 - mse: 0.6715 - val_loss: 0.6392 - val_mse: 0.6392
# Epoch 10/15
# 67/67 [==============================] - 0s 6ms/step - loss: 0.6716 - mse: 0.6716 - val_loss: 0.6518 - val_mse: 0.6518
# Epoch 11/15
# 67/67 [==============================] - 0s 6ms/step - loss: 0.6712 - mse: 0.6712 - val_loss: 0.6308 - val_mse: 0.6308
# Epoch 12/15
# 67/67 [==============================] - 0s 6ms/step - loss: 0.
15
# 67/67 [==============================] - 0s 7ms/step - loss: 0.1010 - mse: 0.1010 - val_loss: 0.0995 - val_mse: 0.0995
# Epoch 15/15
# 67/67 [==============================] - 1s 10ms/step - loss: 0.0992 - mse: 0.0992 - val_loss: 0.0976 - val_mse: 0.0976

# %%
def evals(models,data,bsize,j):   #j=0 for validation data, j=1 for target
    rg=range(len(models))
    scores=list(0 for i in rg)
    tit=('validation data','the exact curve')

    print('evaluate model with '+tit[j]+':'); print()
    for i in rg: scores[i]=models[i].evaluate(data[j+1][0],data[j+1][1], batch_size=bsize, verbose=1)
    loss=tuple(scores[i][0] for i in rg); val=tuple(scores[i][1] for i in rg)
    # print performance
    print(); print('Test loss:'); print(loss)
    print('Test accuracy:'); print(val)

# %%
evals(models1,poly_data,150,0)
# Out:
# evaluate model with validation data:
#
# 7/7 [==============================] - 0s 10ms/step - loss: 0.6349 - mse: 0.6349
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1950 - mse: 0.1950
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3414 - mse: 0.3414
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0976 - mse: 0.0976
#
# Test loss:
# (0.6349015235900879, 0.19495949149131775, 0.3414174020290375, 0.09758810698986053)
# Test accuracy:
# (0.6349015235900879, 0.19495947659015656, 0.3414174020290375, 0.09758810698986053)

# %%
def plot_hist(histories,title):
    many=len(histories)
    for i in range(many):
        plt.subplot(int((many+1)/2),2,i+1)
        losses(histories[i],title[i])
    plt.suptitle('Models losses')
    plt.subplots_adjust(hspace=0.3, wspace=0.3)
    plt.show()
    
def fit(models,data):
    plt.figure(figsize=(15,6))
    for lim in range(2):
        plt.subplot(1,2,lim+1)
        x_pred = np.random.uniform(-lim-1, lim+1, 200)
        plt.plot(xtg,ytg)
        for i in range(len(models)):
            y_pred=models[i].predict(x_pred)
            plt.scatter(x_pred,y_pred,marker='.',label=title[i])
        plt.axvline(x=-1,color='k',linewidth=0.8)
        plt.axvline(x=1,color='k',linewidth=0.8)
        if(lim==0):
            plt.xlim(-1.1,1.1)
            plt.ylim(1,5)
        plt.legend(loc='best')
        plt.grid(True)
        if(lim==0): plt.title('inside training range')
        else: plt.title('outside training range')
    plt.suptitle('NNs predictions')
    plt.show()

# %%
title=('linear model','more neurons NN','more layers NN','more NL NN')
plt.figure(figsize=(12,8))
plot_hist(hist1,title)

# %% [markdown]
# Già da questi grafici è evidente che la NN lineare non sarà mai in grado di fittare la funzione polinomiale di interesse. L'opzione di aumentare simultaneamente numero di layer e di neuroni per layer sembra essere quella che porta alla rete neurale più efficiente. Eseguendo vari test ho inoltre notato che in quest'ultimo caso sembra più efficace far crescere il numero di neuroni (piuttosto che tenerli costanti o farli diminuire) nei layer nascosti muovendosi da quello di input verso quello di output.

# %%
evals(models1,poly_data,150,1)
# Out:
# evaluate model with the exact curve:
#
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5518 - mse: 0.5518
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1062 - mse: 0.1062
# 7/7 [==============================] - 0s 11ms/step - loss: 0.2505 - mse: 0.2505
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0108 - mse: 0.0108
#
# Test loss:
# (0.551773190498352, 0.10620278865098953, 0.25046613812446594, 0.01083307433873415)
# Test accuracy:
# (0.551773190498352, 0.10620278865098953, 0.25046613812446594, 0.01083307433873415)

# %%
fit(models1,poly_data)

# %% [markdown]
# Come era da aspettarsi la NN lineare è del tutto da scartare. Era prevedibile anche il fallimento del test di solo aumento dei layers. In questo secondo caso si cerca infatti in pratica di fittare un polinomio di terzo grado utilizzando in ogni layer solo funzioni risposta monotone. Confrontando errori finali e grafico del fit la scelta migliore sembra essere quella di aumentare contemporaneamente numero di layer e numero di neuroni.
#
# All'esterno del range di training la situazione è del tutto critica in tutti i casi considerati. In effetti si sta chiedendo alla rete di predire il comportamento della funzione target in regioni dello spazio rispetto alle quali non ha ricevuto nessun tipo di informazione in fase di training. E' chiaro che l'esito non può essere in alcun modo affidabile.

# %% [markdown]
# Basandomi su queste osservazioni sono passato a testare delle reti a $5$ layer nascosti e a neuroni multipli ed in numero crescente verso il layer di output, tutte distinte per le diverse funzioni di attivazione.\
# Poichè nel range studiato la funzione assume solo valori positivi si possono anche usare senza problemi funzioni di attivazione aventi come codominio solo il semiasse reale positivo, come la relu. Per l'ultima delle reti utilizzate provo anche ad usare la funzione sigmoide. Questa però è limitata sia inferiormente che superiormente a produrre valori in modulo minori di $1$, e quindi non può essere usata anche per il layer di output se l'obiettivo è quello di rappresentare correttamente la funzione polinomiale oggetto del fit. Per l'ultimo layer di questa NN ho quindi provato a usare ancora una selu.

# %%
def composeNN(activation,big):    #big=1 for a bigger NN, big=2 for 3D case
    rg=(range(4),range(5),range(8)); dim=(1,1,2)
    def par(i): return (3+2*i,5*(i+1),5*(i+1))
    
    #compose the NN model
    model = tf.keras.Sequential()
    model.add(Dense(2,input_shape=(dim[big],),activation=activation))
    for i in rg[big]: model.add(Dense(par(i)[big],activation=activation))
    if(big==2): model.add(Dropout(0.5))
    if activation=='sigmoid': model.add(Dense(1,activation='selu'))
    else: model.add(Dense(1,activation=activation))
    return model

# %%
models_act=(composeNN('selu',0),composeNN('elu',0),composeNN('relu',0),composeNN('sigmoid',0))
compileNN(models_act,SGD(),'mse','mse')
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_35 (Dense)             (None, 2)                 4
# _________________________________________________________________
# dense_36 (Dense)             (None, 3)                 9
# _________________________________________________________________
# dense_37 (Dense)             (None, 5)                 20
# _________________________________________________________________
# dense_38 (Dense)             (None, 7)                 42
# _________________________________________________________________
# dense_39 (Dense)             (None, 9)                 72
# _________________________________________________________________
# dense_40 (Dense)             (None, 1)                 10
# =================================================================
# Total params: 157
# Trainable params: 157
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_41 (Dense)             (None, 2)                 4
# _________________________________________________________________
# dense_42 (Dense)             (None, 3)                 9
# _________________________________________________________________
# dense_43 (Dense)             (None, 5)                 20
# _________________________________________________________________
# dense_44 (Dense)             (None, 7)                 42
# _________________________________________________________________
# dense_45 (Dense)             (None, 9)                 72
# _________________________________________________________________
# dense_46 (Dense)             (None, 1)                 10
# =================================================================
# Total params: 157
# Trainable params: 157
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_47 (Dense)             (None, 2)                 4
# _________________________________________________________________
# dense_48 (Dense)             (None, 3)                 9
# _________________________________________________________________
# dense_49 (Dense)             (None, 5)                 20
# _________________________________________________________________
# dense_50 (Dense)             (None, 7)                 42
# _________________________________________________________________
# dense_51 (Dense)             (None, 9)                 72
# _________________________________________________________________
# dense_52 (Dense)             (None, 1)                 10
# =================================================================
# Total params: 157
# Trainable params: 157
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_53 (Dense)             (None, 2)                 4
# _________________________________________________________________
# dense_54 (Dense)             (None, 3)                 9
# _________________________________________________________________
# dense_55 (Dense)             (None, 5)                 20
# _________________________________________________________________
# dense_56 (Dense)             (None, 7)                 42
# _________________________________________________________________
# dense_57 (Dense)             (None, 9)                 72
# _________________________________________________________________
# dense_58 (Dense)             (None, 1)                 10
# =================================================================
# Total params: 157
# Trainable params: 157
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist_act = history(models_act,poly_data,150,15)
# Out:
# Epoch 1/15
# 67/67 [==============================] - 1s 12ms/step - loss: 0.5086 - mse: 0.5086 - val_loss: 0.1611 - val_mse: 0.1611
# Epoch 2/15
# 67/67 [==============================] - 1s 8ms/step - loss: 0.1386 - mse: 0.1386 - val_loss: 0.1210 - val_mse: 0.1210
# Epoch 3/15
# 67/67 [==============================] - 0s 7ms/step - loss: 0.1122 - mse: 0.1122 - val_loss: 0.1053 - val_mse: 0.1053
# Epoch 4/15
# 67/67 [==============================] - 0s 6ms/step - loss: 0.1038 - mse: 0.1038 - val_loss: 0.1000 - val_mse: 0.1000
# Epoch 5/15
# 67/67 [==============================] - 1s 8ms/step - loss: 0.0989 - mse: 0.0989 - val_loss: 0.0982 - val_mse: 0.0982
# Epoch 6/15
# 67/67 [==============================] - 1s 11ms/step - loss: 0.0975 - mse: 0.0975 - val_loss: 0.0962 - val_mse: 0.0962
# Epoch 7/15
# 67/67 [==============================] - 1s 7ms/step - loss: 0.0968 - mse: 0.0968 - val_loss: 0.0951 - val_mse: 0.0951
# Epoch 8/15
# 67/67 [==============================] - 1s 11ms/step - loss: 0.0946 - mse: 0.0946 - val_loss: 0.0971 - val_mse: 0.0971
# Epoch 9/15
# 67/67 [==============================] - 0s 7ms/step - loss: 0.0954 - mse: 0.0954 - val_loss: 0.1006 - val_mse: 0.1006
# Epoch 10/15
# 67/67 [==============================] - 0s 7ms/step - loss: 0.0946 - mse: 0.0946 - val_loss: 0.0925 - val_mse: 0.0925
# Epoch 11/15
# 67/67 [==============================] - 1s 8ms/step - loss: 0.0932 - mse: 0.0932 - val_loss: 0.0970 - val_mse: 0.0970
# Epoch 12/15
# 67/67 [==============================] - 0s 7ms/step - loss: 0.0936 - mse: 0.0936 - val_loss: 0.0922 - val_mse: 0.0922
# Epoch 13/15
# 67/67 [==============================] - 1s 8ms/step - loss: 0.0940 - mse: 0.0940 - val_loss: 0.1019 - val_mse: 0.1019
# Epoch 14/15
# 67/67 [==============================] - 0s 7ms/step - loss: 0.0936 - mse: 0.0936 - val_loss: 0.0911 - val_mse: 0.0911
# Epoch 15/15
# 67/67 [==============================] - 0s 7ms/step - loss: 0.0939 - mse: 0.0939 - val_loss: 0.0922 - val_mse: 0.0922
# Epoch 1/15
# 67/67 [==============================] - 1s 20ms/step - loss: 1.9350 - mse: 1.9350 - val_loss: 0.4208 - val_mse: 0.4208
# Epoch 2/15
# 67/67 [==============================] - 1s 14ms/step - loss: 0.4314 - mse: 0.4314 - val_loss: 0.3902 - val_mse: 0.3902
# Epoch 3/15
# 67/67 [==============================] - 1s 10ms/step - loss: 0.4136 - mse: 0.4136 - val_loss: 0.3793 - val_mse: 0.3793
# Epoch 4/15
# 67/67 [==============================] - 1s 9ms/step - loss: 0.4027 - mse: 0.4027 - val_loss: 0.3743 - val_mse: 0.3743
# Epoch 5/15
# 67/67 [==============================] - 1s 8ms/step - loss: 0.3936 - mse: 0.3936 - val_loss: 0.3630 - val_mse: 0.3630
# Epoch 6/15
# 67/67 [==============================] - 0s 5ms/step - loss: 0.3833 - mse: 0.3833 - val_loss: 0.3533 - val_mse: 0.3533
# Epoch 7/15
# 67/67 [==============================] - 0s 6ms/step - loss: 0.
# 67/67 [==============================] - 0s 7ms/step - loss: 1.1118 - mse: 1.1118 - val_loss: 1.1118 - val_mse: 1.1118
# Epoch 7/15
# 67/67 [==============================] - 0s 7ms/step - loss: 1.1122 - mse: 1.1122 - val_loss: 1.1106 - val_mse: 1.1106
# Epoch 8/15
# 67/67 [==============================] - 0s 7ms/step - loss: 1.1118 - mse: 1.1118 - val_loss: 1.1108 - val_mse: 1.1108
# Epoch 9/15
# 67/67 [==============================] - 0s 7ms/step - loss: 1.1120 - mse: 1.1120 - val_loss: 1.1107 - val_mse: 1.1107
# Epoch 10/15
# 67/67 [==============================] - 0s 7ms/step - loss: 1.1118 - mse: 1.1118 - val_loss: 1.1111 - val_mse: 1.1111
# Epoch 11/15
# 67/67 [==============================] - 0s 7ms/step - loss: 1.1116 - mse: 1.1116 - val_loss: 1.1103 - val_mse: 1.1103
# Epoch 12/15
# 67/67 [==============================] - 0s 7ms/step - loss: 1.1116 - mse: 1.1116 - val_loss: 1.1110 - val_mse: 1.1110
# Epoch 13/15
# 67/67 [==============================] - 0s 7ms/step - loss: 1.1115 - mse: 1.1115 - val_loss: 1.1106 - val_mse: 1.1106
# Epoch 14/15
# 67/67 [==============================] - 0s 7ms/step - loss: 1.1119 - mse: 1.1119 - val_loss: 1.1107 - val_mse: 1.1107
# Epoch 15/15
# 67/67 [==============================] - 1s 8ms/step - loss: 1.1113 - mse: 1.1113 - val_loss: 1.1100 - val_mse: 1.1100

# %%
evals(models_act,poly_data,150,0)
# Out:
# evaluate model with validation data:
#
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0922 - mse: 0.0922
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1630 - mse: 0.1630
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2017 - mse: 0.2017
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1100 - mse: 1.1100
#
# Test loss:
# (0.0921618789434433, 0.16304168105125427, 0.20174655318260193, 1.110007405281067)
# Test accuracy:
# (0.0921618789434433, 0.16304168105125427, 0.20174655318260193, 1.1100075244903564)

# %%
title=('selu','elu','relu','sigmoid')
plt.figure(figsize=(12,8))
plot_hist(hist_act,title)

# %% [markdown]
# Evidentemente l'utilizzo delle sigmoidi è da escludere.

# %%
evals(models_act,poly_data,150,1)
# Out:
# evaluate model with the exact curve:
#
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0039 - mse: 0.0039
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0754 - mse: 0.0754
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1139 - mse: 0.1139
# 7/7 [==============================] - 0s 4ms/step - loss: 1.0384 - mse: 1.0384
#
# Test loss:
# (0.003850332461297512, 0.07535959780216217, 0.11385221779346466, 1.0383676290512085)
# Test accuracy:
# (0.003850332461297512, 0.07535959780216217, 0.11385221779346466, 1.0383676290512085)

# %%
fit(models_act,poly_data)

# %% [markdown]
# La funzione selu sembra quella su cui puntare per questo problema (anche se non è escluso che in realtà le altre risultino più adatte cambiando l'ottimizzatore o la loss function; non eseguirò questo test). Nel seguito continuerò ad utilizzare questa funzione di attivazione.
#
# Chiaramente le predizioni all'esterno del range di training sono ancora del tutto sbagliate.

# %% [markdown]
# Provo ora a variare metodo di ottimizzazione (in particolare testo l'utilizzo di *Adadelta* e *Adam*, più sofisticati del semplice *stochastic gradient descent* usato finora) e loss function (proverò la MAE, *mean absolute error* e la MSLE, *mean squared logarithmic error*), mantenendo come funzione di attivazione sempre la selu e utilizzando delle reti composte da $5$ layer interni a neuroni crescenti e uno di output (obbligatoriamente) a singolo neurone.

# %%
models_poly=list(composeNN('selu',1) for i in range(6))
models_poly[0].compile(optimizer=SGD(),loss='mse',metrics=['mse'])
models_poly[1].compile(optimizer=Adadelta(),loss='mse',metrics=['mse'])
models_poly[2].compile(optimizer=Adadelta(),loss='mae',metrics=['mae'])
models_poly[3].compile(optimizer=Adam(),loss='mse',metrics=['mse'])
models_poly[4].compile(optimizer=Adam(),loss='mae',metrics=['mae'])
models_poly[5].compile(optimizer=Adam(),loss='msle',metrics=['msle'])
for mod in models_poly: mod.summary(); print()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_59 (Dense)             (None, 2)                 4
# _________________________________________________________________
# dense_60 (Dense)             (None, 5)                 15
# _________________________________________________________________
# dense_61 (Dense)             (None, 10)                60
# _________________________________________________________________
# dense_62 (Dense)             (None, 15)                165
# _________________________________________________________________
# dense_63 (Dense)             (None, 20)                320
# _________________________________________________________________
# dense_64 (Dense)             (None, 25)                525
# _________________________________________________________________
# dense_65 (Dense)             (None, 1)                 26
# =================================================================
# Total params: 1,115
# Trainable params: 1,115
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_66 (Dense)             (None, 2)                 4
# _________________________________________________________________
# dense_67 (Dense)             (None, 5)                 15
# _________________________________________________________________
# dense_68 (Dense)             (None, 10)                60
# _________________________________________________________________
# dense_69 (Dense)             (None, 15)                165
# _________________________________________________________________
# dense_70 (Dense)             (None, 20)                320
# _________________________________________________________________
# dense_71 (Dense)             (None, 25)                525
# _________________________________________________________________
# dense_72 (Dense)             (None, 1)                 26
# =================================================================
# Total params: 1,115
# Trainable params: 1,115
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_73 (Dense)             (None, 2)                 4
# _________________________________________________________________
# dense_74 (Dense)             (None, 5)                 15
# _________________________________________________________________
# dense_75 (Dense)             (None, 10)                60
# _________________________________________________________________
# dense_76 (Dense)             (None, 15)                165
# _________________________________________________________________
# dense_77 (Dense)             (None, 20)                320
# _________________________________________________________________
# dense_78 (Dense)             (None, 25)                525
# _________________________________________________________________
# dense_79 (Dense)             (None, 1)                 26
# =================================================================
# Total params: 1,115
# Trainable params: 1,115
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_80 (Dense)             (None, 2)                 4
# _________________________________________________________________
# dense_81 (Dense)             (None, 5)                 15
# _________________________________________________________________
# dense_82 (Dense)             (None, 10)                60
# _________________________________________________________________
# dense_83 (Dense)             (None, 15)                165
# _________________________________________________________________
# dense_84 (Dense)             (None, 20)                320
# _________________________________________________________________
# dense_85 (Dense)             (None, 25)                525
# _________________________________________________________________
# dense_86 (Dense)             (None, 1)                 26
# =================================================================
# Total params: 1,115
# Trainable params: 1,115
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_87 (Dense)             (None, 2)                 4
# _________________________________________________________________
# dense_88 (Dense)             (None, 5)                 15
# _________________________________________________________________
# dense_89 (Dense)             (None, 10)                60
# _________________________________________________________________
# dense_90 (Dense)             (None, 15)                165
# _________________________________________________________________
# dense_91 (Dense)             (None, 20)                320
# _________________________________________________________________
# dense_92 (Dense)             (None, 25)                525
# _________________________________________________________________
# dense_93 (Dense)             (None, 1)                 26
# =================================================================
# Total params: 1,115
# Trainable params: 1,115
# Non-trainable params: 0
# _________________________________________________________________
#
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_94 (Dense)             (None, 2)                 4
# _________________________________________________________________
# dense_95 (Dense)             (None, 5)                 15
# _________________________________________________________________
# dense_96 (Dense)             (None, 10)                60
# _________________________________________________________________
# dense_97 (Dense)             (None, 15)                165
# _________________________________________________________________
# dense_98 (Dense)             (None, 20)                320
# _________________________________________________________________
# dense_99 (Dense)             (None, 25)                525
# _________________________________________________________________
# dense_100 (Dense)            (None, 1)                 26
# =================================================================
# Total params: 1,115
# Trainable params: 1,115
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Dopo una prima prova ho visto che per entrambe le reti ottimizzate con *Adadelta* serve un numero di epoche maggiore, almeno $N_{epochs}=100$, per arrivare a valori accettabili della loss.

# %%
hist_poly = history(models_poly,poly_data,150,(15,100,100,15,15,15))
# Out:
# Epoch 1/15
# 67/67 [==============================] - 1s 14ms/step - loss: 0.6997 - mse: 0.6997 - val_loss: 0.6073 - val_mse: 0.6073
# Epoch 2/15
# 67/67 [==============================] - 1s 8ms/step - loss: 0.2148 - mse: 0.2148 - val_loss: 0.2813 - val_mse: 0.2813
# Epoch 3/15
# 67/67 [==============================] - 1s 8ms/step - loss: 0.1739 - mse: 0.1739 - val_loss: 0.1182 - val_mse: 0.1182
# Epoch 4/15
# 67/67 [==============================] - 1s 9ms/step - loss: 0.1454 - mse: 0.1454 - val_loss: 0.1763 - val_mse: 0.1763
# Epoch 5/15
# 67/67 [==============================] - 1s 11ms/step - loss: 0.1560 - mse: 0.1560 - val_loss: 0.1400 - val_mse: 0.1400
# Epoch 6/15
# 67/67 [==============================] - 1s 9ms/step - loss: 0.1225 - mse: 0.1225 - val_loss: 0.1234 - val_mse: 0.1234
# Epoch 7/15
# 67/67 [==============================] - 1s 8ms/step - loss: 0.1097 - mse: 0.1097 - val_loss: 0.1070 - val_mse: 0.1070
# Epoch 8/15
# 67/67 [==============================] - 1s 8ms/step - loss: 0.1356 - mse: 0.1356 - val_loss: 0.1183 - val_mse: 0.1183
# Epoch 9/15
# 67/67 [==============================] - 1s 8ms/step - loss: 0.1081 - mse: 0.1081 - val_loss: 0.1436 - val_mse: 0.1436
# Epoch 10/15
# 67/67 [==============================] - 0s 7ms/step - loss: 0.1229 - mse: 0.1229 - val_loss: 0.1112 - val_mse: 0.1112
# Epoch 11/15
# 67/67 [==============================] - 1s 8ms/step - loss: 0.1178 - mse: 0.1178 - val_loss: 0.0965 - val_mse: 0.0965
# Epoch 12/15
# 67/67 [==============================] - 0s 7ms/step - loss: 0.1082 - mse: 0.1082 - val_loss: 0.1211 - val_mse: 0.1211
# Epoch 13/15
# 67/67 [==============================] - 1s 8ms/step - loss: 0.1025 - mse: 0.1025 - val_loss: 0.1109 - val_mse: 0.1109
# Epoch 14/15
# 67/67 [==============================] - 1s 8ms/step - loss: 0.1063 - mse: 0.1063 - val_loss: 0.1043 - val_mse: 0.1043
# Epoch 15/15
# 67/67 [==============================] - 0s 7ms/step - loss: 0.0999 - mse: 0.0999 - val_loss: 0.0983 - val_mse: 0.0983
# Epoch 1/100
# 67/67 [==============================] - 1s 16ms/step - loss: 11.2167 - mse: 11.2167 - val_loss: 11.3939 - val_mse: 11.3939
# Epoch 2/100
# 67/67 [==============================] - 1s 8ms/step - loss: 11.1688 - mse: 11.1688 - val_loss: 11.3433 - val_mse: 11.3433
# Epoch 3/100
# 67/67 [==============================] - 1s 12ms/step - loss: 11.1180 - mse: 11.1180 - val_loss: 11.2901 - val_mse: 11.2901
# Epoch 4/100
# 67/67 [==============================] - 1s 9ms/step - loss: 11.0647 - mse: 11.0647 - val_loss: 11.2344 - val_mse: 11.2344
# Epoch 5/100
# 67/67 [==============================] - 1s 10ms/step - loss: 11.0090 - mse: 11.0090 - val_loss: 11.1763 - val_mse: 11.1763
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0068 - msle: 0.0068
#
# Test loss:
# (0.09830020368099213, 1.032591462135315, 0.8796142935752869, 0.09340547770261765, 0.24788792431354523, 0.006768760271370411)
# Test accuracy:
# (0.09830020368099213, 1.0325915813446045, 0.8796142935752869, 0.09340547770261765, 0.24788792431354523, 0.006768760271370411)

# %%
title=('SGD, MSE','Adadelta, MSE','Adadelta, MAE','Adam, MSE','Adam, MAE','Adam, MSLE')
plt.figure(figsize=(12,12))
plot_hist(hist_poly,title)

# %%
evals(models_poly,poly_data,150,1)
# Out:
# evaluate model with the exact curve:
#
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0098 - mse: 0.0098
# 7/7 [==============================] - 0s 7ms/step - loss: 0.9529 - mse: 0.9529
# 7/7 [==============================] - 0s 6ms/step - loss: 0.8377 - mae: 0.8377
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0059 - mse: 0.0059
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0897 - mae: 0.0897
# 7/7 [==============================] - 0s 5ms/step - loss: 8.4257e-04 - msle: 8.4257e-04
#
# Test loss:
# (0.009761916473507881, 0.9528563022613525, 0.8377494215965271, 0.005876298528164625, 0.08967077732086182, 0.0008425711421296)
# Test accuracy:
# (0.009761916473507881, 0.9528563022613525, 0.8377494215965271, 0.005876298528164625, 0.08967077732086182, 0.000842571200337261)

# %%
fit(models_poly,poly_data)

# %% [markdown]
# Per capire quale sia l'opzione migliore adesso bisogna fare attenzione, perché le loss valutate sono differenti. Sicuramente le due reti che utilizzano *Adadelta* possono essere scartate. Certamente facendo proseguire il train per un numero maggiore di epoche le prestazioni di queste NN potrebbero migliorare, ma allora è meglio concentrarsi sulle altre opzioni, più efficienti. La prima rete è scartata sia dal fit grafico che dal confronto della loss con la prima delle reti *Adam*. Queste tre giungono a dei fit di qualità simile. Nell'ultimo esercizio sarà questo l'ottimizzatore utilizzato.

# %% [markdown]
# In conclusione per una NN è fondamentale innanzitutto avere un set piuttosto grande di dati di training: più questi sono numerosi più l'apprendimento della macchina è efficiente e le sue previsioni sono accurate. Questo vale però solamente per predizioni all'interno del range di valori in cui la rete è stata trainata. All'esterno di esso la rete non ha alcuna informazione sull'andamento della funzione che sta fittando, e quindi le previsioni risultano qui del tutto inaffidabili.
#
# E' inoltre importante anche valutare l'andamento delle loss in funzione del numero di epoche, per capire sia se l'apprendimento ha raggiunto una qualche convergenza (e quindi il numero di epoche scelte può essere valutato sufficiente) sia per essere sicuri di non fare overfitting.
#
# Tipicamente piuttosto che aumentare la complessità della rete (cosa che porta ad un aumento anche significativo del peso computazionale) è preferibile aumentare il numero di dati forniti ad essa in fase di training ("bias-variance tradeoff"). Nel caso in cui questo non sia possibile allora un aumento del numero di neuroni per layer può essere necessario, e un corrispondente aumento di layer può portare ad un efficienza significativamente migliore a parità di complessità della rete. Bisogna però in questo caso sempre stare attenti non solo all'aumento del costo computazionale delle operazioni di training, ma anche e soprattutto al pericolo di overfitting, situazione in cui la rete è troppo complessa in relazione al numero di dati forniti e comincia quindi a fittarne il rumore sperimentale.
#
# In generale è necessario avere funzioni di attivazione non lineari. In caso contrario la rete può solo generare mappe che sono, appunto, lineari. Sembra inoltre preferibile scegliere funzioni non limitate, almeno nei casi di funzioni target non limitate come quelle trattate. I limiti della funzione attivazione sembrano in caso contrario essere un ostacolo nel processo di ottimizzazione.\
# Particolare attenzione va prestata alla funzione di attivazione dell'ultimo layer, che deve se possibile essere scelta in funzione delle conoscenze a priori sugli output. Se per esempio la funzione target può produrre anche valori negativi una funzione di attivazione definita positiva, come la relu, non può essere scelta per il layer di output, che non sarebbe altrimenti in grado di produrre in alcun modo valori negativi in uscita.
#
# Come ottimizzatore *Adam* sembra molto buono, ma deve spesso essere accoppiato a dei layer di dropout per evitare overfitting.\
# Non ho notato particolari differenze tra diverse scelte delle funzioni costo.

# %% [markdown]
# ### Esercizio 11.3
#
# Nell'ultimo esercizio i dati da fittare sono generati dalla funzione bidimensionale $f(x,y) = \sin(x^2+y^2)$ nel range $x \in [-3/2,3/2]$ e $y \in [-3/2,3/2]$. La rete neurale è simile alle ultime utilizzate nel problema precedente, ma più complessa. L'ottimizzatore utilizzato è *Adam*, la funzione di attivazione è la selu e la funzione costo la MSE. I dati hanno un rumore gaussiano con $\sigma=0.3$ e ho usato $N_{train}=10^5$ e $N_{valid}=10^4$.

# %%
def target3D(x,y): return np.sin(x**2 + y**2)

def plot3D(xyz,target,lab):
    fig = plt.figure()
    ax = Axes3D(fig)
    ax.plot_trisurf(target[0],target[1],target[2],linewidth=0,antialiased=False,alpha=0.3)
    ax.scatter(xyz[0],xyz[1],xyz[2],c=xyz[2],marker='.')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')
    ax.view_init(30, 30)
    plt.title('Target and '+lab, y=1.05)
    plt.show()

# %%
sigma=0.3
#generate training data
x_train = np.random.uniform(-1.5, 1.5, int(1e5))
y_train = np.random.uniform(-1.5, 1.5, int(1e5))
train = np.stack([x_train,y_train],axis=1)  #actual measures from which we want to guess regression parameters
z_train = np.random.normal(target3D(x_train,y_train),sigma)
#generate validation data
x_valid = np.random.uniform(-1.5, 1.5, int(1e4))
y_valid = np.random.uniform(-1.5, 1.5, int(1e4))
valid = np.stack([x_valid,y_valid],axis=1)
z_valid = np.random.normal(target3D(x_valid,y_valid),sigma)
# ideal (target) function for error evaluation
x_target=x_valid; y_target=y_valid
target = np.stack([x_target,y_target],axis=1)
z_target = target3D(x_target,y_target)
#x_target only for the graph
xtg=[np.random.uniform(-1.5, 1.5, 5000) for i in ('x','y')]
targ=np.stack([xtg[0],xtg[1],target3D(xtg[0],xtg[1])],axis=0)

plot3D((x_valid,y_valid,z_valid),targ,'validation')

# %%
mod3D=composeNN('selu',2)
mod3D.compile(optimizer=Adam(),loss='mse',metrics=['mse'])
mod3D.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_101 (Dense)            (None, 2)                 6
# _________________________________________________________________
# dense_102 (Dense)            (None, 5)                 15
# _________________________________________________________________
# dense_103 (Dense)            (None, 10)                60
# _________________________________________________________________
# dense_104 (Dense)            (None, 15)                165
# _________________________________________________________________
# dense_105 (Dense)            (None, 20)                320
# _________________________________________________________________
# dense_106 (Dense)            (None, 25)                525
# _________________________________________________________________
# dense_107 (Dense)            (None, 30)                780
# _________________________________________________________________
# dense_108 (Dense)            (None, 35)                1085
# _________________________________________________________________
# dense_109 (Dense)            (None, 40)                1440
# _________________________________________________________________
# dropout (Dropout)            (None, 40)                0
# _________________________________________________________________
# dense_110 (Dense)            (None, 1)                 41
# =================================================================
# Total params: 4,437
# Trainable params: 4,437
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist3D = mod3D.fit(x=train,y=z_train,batch_size=500,epochs=15,shuffle=True,validation_data=(valid,z_valid))
# Out:
# Epoch 1/15
# 200/200 [==============================] - 3s 14ms/step - loss: 0.2887 - mse: 0.2887 - val_loss: 0.1786 - val_mse: 0.1786
# Epoch 2/15
# 200/200 [==============================] - 3s 13ms/step - loss: 0.1808 - mse: 0.1808 - val_loss: 0.1560 - val_mse: 0.1560
# Epoch 3/15
# 200/200 [==============================] - 2s 12ms/step - loss: 0.1615 - mse: 0.1615 - val_loss: 0.1413 - val_mse: 0.1413
# Epoch 4/15
# 200/200 [==============================] - 2s 12ms/step - loss: 0.1457 - mse: 0.1457 - val_loss: 0.1240 - val_mse: 0.1240
# Epoch 5/15
# 200/200 [==============================] - 2s 12ms/step - loss: 0.1318 - mse: 0.1318 - val_loss: 0.1120 - val_mse: 0.1120
# Epoch 6/15
# 200/200 [==============================] - 3s 15ms/step - loss: 0.1214 - mse: 0.1214 - val_loss: 0.1112 - val_mse: 0.1112
# Epoch 7/15
# 200/200 [==============================] - 3s 14ms/step - loss: 0.1175 - mse: 0.1175 - val_loss: 0.1038 - val_mse: 0.1038
# Epoch 8/15
# 200/200 [==============================] - 3s 14ms/step - loss: 0.1158 - mse: 0.1158 - val_loss: 0.1142 - val_mse: 0.1142
# Epoch 9/15
# 200/200 [==============================] - 2s 12ms/step - loss: 0.1138 - mse: 0.1138 - val_loss: 0.1020 - val_mse: 0.1020
# Epoch 10/15
# 200/200 [==============================] - 2s 12ms/step - loss: 0.1132 - mse: 0.1132 - val_loss: 0.1080 - val_mse: 0.1080
# Epoch 11/15
# 200/200 [==============================] - 2s 12ms/step - loss: 0.1099 - mse: 0.1099 - val_loss: 0.1054 - val_mse: 0.1054
# Epoch 12/15
# 200/200 [==============================] - 2s 12ms/step - loss: 0.1107 - mse: 0.1107 - val_loss: 0.1004 - val_mse: 0.1004
# Epoch 13/15
# 200/200 [==============================] - 3s 16ms/step - loss: 0.1084 - mse: 0.1084 - val_loss: 0.1014 - val_mse: 0.1014
# Epoch 14/15
# 200/200 [==============================] - 2s 10ms/step - loss: 0.1075 - mse: 0.1075 - val_loss: 0.1008 - val_mse: 0.1008
# Epoch 15/15
# 200/200 [==============================] - 1s 6ms/step - loss: 0.1071 - mse: 0.1071 - val_loss: 0.0985 - val_mse: 0.0985

# %%
# evaluate model
score = mod3D.evaluate(valid,z_valid, batch_size=500, verbose=1)
# print performance, validation set
print()
print('Test loss:    ',score[0])
print('Test accuracy:',score[1])
# Out:
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0985 - mse: 0.0985
#
# Test loss:     0.09854353219270706
# Test accuracy: 0.09854353219270706

# %%
losses(hist3D,'Model loss')

x_pred=np.random.uniform(-1.5, 1.5, int(1e3))
y_pred=np.random.uniform(-1.5, 1.5, int(1e3))
pred=np.stack([x_pred,y_pred],axis=1)
z_pred=mod3D.predict(pred)
plot3D((x_pred,y_pred,z_pred[:,0]),targ,'predicted')

# %% [markdown]
# La regressione è riuscita.
